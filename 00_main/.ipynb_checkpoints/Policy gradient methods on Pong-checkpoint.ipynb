# %% [markdown]
# # Policy gradient methods on Pong
#
# The three main differences from the previous example's code are as follows:
# - The baseline is estimated with a moving average for 1M past transitions,
# instead of all examples
# - Several concurrent environments are used
# - Gradients are clipped to improve training stability
#
# To make moving average calculations faster, a deque-backed buffer is created.

# %%
import gym
import ptan
import numpy as np
import argparse
import collections
from tensorboardX import SummaryWriter
import sys 
sys.path.append("../Chapter11/")

import torch
import torch.nn.functional as F
import torch.nn.utils as nn_utils
import torch.optim as optim

from lib import common

GAMMA = 0.99
LEARNING_RATE = 0.0001
ENTROPY_BETA = 0.01
BATCH_SIZE = 128

REWARD_STEPS = 10
BASELINE_STEPS = 1000000
GRAD_L2_CLIP = 0.1

ENV_COUNT = 32

# %%
def make_env():
    return ptan.common.wrappers.wrap_dqn(gym.make("PongNoFrameskip-v4"))


class MeanBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.deque = collections.deque(maxlen=capacity)
        self.sum = 0.0

    def add(self, val):
        if len(self.deque) == self.capacity:
            self.sum -= self.deque[0]
        self.deque.append(val)
        self.sum += val

    def mean(self):
        if not self.deque:
            return 0.0
        return self.sum / len(self.deque)

# %% [markdown]
# The second difference in this example is working with multiple environments, and this functionality is supported by the PTAN library. The only action we have to take is to pass the array of Env objects to the ExperienceSource class. All the rest is done automatically. In the case of several environments, the experience source
# asks them for transitions in round-robin, providing us with less-correlated training
# samples. The last difference from the CartPole example is gradient clipping, which
# is performed using the PyTorch clip_grad_norm function from the torch.nn.utils
# package.

# %%
device = torch.device("cuda")

envs = [make_env() for _ in range(ENV_COUNT)]
writer = SummaryWriter(comment="-pong-pg-" + "First")

net = common.AtariPGN(envs[0].observation_space.shape, envs[0].action_space.n).to(device)
print(net)

agent = ptan.agent.PolicyAgent(net, apply_softmax=True, device=device)
exp_source = ptan.experience.ExperienceSourceFirstLast(envs, agent, gamma=GAMMA, steps_count=REWARD_STEPS)

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE, eps=1e-3)

total_rewards = []
step_idx = 0
done_episodes = 0
train_step_idx = 0
baseline_buf = MeanBuffer(BASELINE_STEPS)

batch_states, batch_actions, batch_scales = [], [], []
m_baseline, m_batch_scales, m_loss_entropy, m_loss_policy, m_loss_total = [], [], [], [], []
m_grad_max, m_grad_mean = [], []
sum_reward = 0.0

with common.RewardTracker(writer, stop_reward=18) as tracker:
    for step_idx, exp in enumerate(exp_source):
        baseline_buf.add(exp.reward)
        baseline = baseline_buf.mean()
        batch_states.append(np.array(exp.state, copy=False))
        batch_actions.append(int(exp.action))
        batch_scales.append(exp.reward - baseline)

        # handle new rewards
        new_rewards = exp_source.pop_total_rewards()
        if new_rewards:
            if tracker.reward(new_rewards[0], step_idx):
                break

        if len(batch_states) < BATCH_SIZE:
            continue

        train_step_idx += 1
        states_v = torch.FloatTensor(np.array(batch_states, copy=False)).to(device)
        batch_actions_t = torch.LongTensor(batch_actions).to(device)

        scale_std = np.std(batch_scales)
        batch_scale_v = torch.FloatTensor(batch_scales).to(device)

        optimizer.zero_grad()
        logits_v = net(states_v)
        log_prob_v = F.log_softmax(logits_v, dim=1)
        log_prob_actions_v = batch_scale_v * log_prob_v[range(BATCH_SIZE), batch_actions_t]
        loss_policy_v = -log_prob_actions_v.mean()

        prob_v = F.softmax(logits_v, dim=1)
        entropy_v = -(prob_v * log_prob_v).sum(dim=1).mean()
        entropy_loss_v = -ENTROPY_BETA * entropy_v
        loss_v = loss_policy_v + entropy_loss_v
        loss_v.backward()
        nn_utils.clip_grad_norm_(net.parameters(), GRAD_L2_CLIP)
        optimizer.step()

        # calc KL-div
        new_logits_v = net(states_v)
        new_prob_v = F.softmax(new_logits_v, dim=1)
        kl_div_v = -((new_prob_v / prob_v).log() * prob_v).sum(dim=1).mean()
        writer.add_scalar("kl", kl_div_v.item(), step_idx)

        grad_max = 0.0
        grad_means = 0.0
        grad_count = 0
        for p in net.parameters():
            grad_max = max(grad_max, p.grad.abs().max().item())
            grad_means += (p.grad ** 2).mean().sqrt().item()
            grad_count += 1

        writer.add_scalar("baseline", baseline, step_idx)
        writer.add_scalar("entropy", entropy_v.item(), step_idx)
        writer.add_scalar("batch_scales", np.mean(batch_scales), step_idx)
        writer.add_scalar("batch_scales_std", scale_std, step_idx)
        writer.add_scalar("loss_entropy", entropy_loss_v.item(), step_idx)
        writer.add_scalar("loss_policy", loss_policy_v.item(), step_idx)
        writer.add_scalar("loss_total", loss_v.item(), step_idx)
        writer.add_scalar("grad_l2", grad_means / grad_count, step_idx)
        writer.add_scalar("grad_max", grad_max, step_idx)

        batch_states.clear()
        batch_actions.clear()
        batch_scales.clear()

writer.close()
# Out:
# AtariPGN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
# )
# 23869: done 1 games, mean reward -21.000, speed 497.59 f/s
# 24494: done 2 games, mean reward -21.000, speed 506.98 f/s
# 24593: done 3 games, mean reward -21.000, speed 502.76 f/s
# 24628: done 4 games, mean reward -21.000, speed 517.76 f/s
# 24794: done 5 games, mean reward -21.000, speed 476.07 f/s
# 24811: done 6 games, mean reward -21.000, speed 557.85 f/s
# 24860: done 7 games, mean reward -21.000, speed 431.39 f/s
# 24891: done 8 games, mean reward -21.000, speed 474.12 f/s
# 25810: done 9 games, mean reward -21.000, speed 493.20 f/s
# 25849: done 10 games, mean reward -21.000, speed 541.70 f/s
# 26774: done 11 games, mean reward -21.000, speed 507.03 f/s
# 27416: done 12 games, mean reward -20.917, speed 512.23 f/s
# 28104: done 13 games, mean reward -20.923, speed 527.83 f/s
# 28323: done 14 games, mean reward -20.857, speed 489.91 f/s
# 28621: done 15 games, mean reward -20.867, speed 495.27 f/s
# 29150: done 16 games, mean reward -20.812, speed 502.24 f/s
# 29163: done 17 games, mean reward -20.765, speed 474.44 f/s
# 29509: done 18 games, mean reward -20.778, speed 502.44 f/s
# 29894: done 19 games, mean reward -20.737, speed 510.23 f/s
# 30153: done 20 games, mean reward -20.700, speed 512.07 f/s
# 30167: done 21 games, mean reward -20.667, speed 461.50 f/s
# 30288: done 22 games, mean reward -20.636, speed 503.93 f/s
# 30602: done 23 games, mean reward -20.652, speed 474.76 f/s
# 30808: done 24 games, mean reward -20.625, speed 528.87 f/s
# 31520: done 25 games, mean reward -20.600, speed 511.46 f/s
# 32141: done 26 games, mean reward -20.577, speed 514.02 f/s
# 32155: done 27 games, mean reward -20.556, speed 483.00 f/s
# 33235: done 28 games, mean reward -20.536, speed 493.05 f/s
# 33283: done 29 games, mean reward -20.552, speed 447.46 f/s
# 33499: done 30 games, mean reward -20.500, speed 509.03 f/s
# 37659: done 31 games, mean reward -20.387, speed 512.61 f/s
# 40281: done 32 games, mean reward -20.312, speed 520.96 f/s
# 49565: done 33 games, mean reward -20.333, speed 516.91 f/s
# 49970: done 34 games, mean reward -20.353, speed 505.00 f/s
# 50851: done 35 games, mean reward -20.371, speed 511.21 f/s
# 51072: done 36 games, mean reward -20.389, speed 500.62 f/s
# 51684: done 37 games, mean reward -20.378, speed 515.11 f/s
# 53535: done 38 games, mean reward -20.395, speed 516.98 f/s
# 53560: done 39 games, mean reward -20.410, speed 488.16 f/s
# 54039: done 40 games, mean reward -20.400, speed 481.77 f/s
# 54444: done 41 games, mean reward -20.415, speed 483.39 f/s
# 54737: done 42 games, mean reward -20.381, speed 495.13 f/s
# 56337: done 43 games, mean reward -20.395, speed 504.89 f/s
# 56414: done 44 games, mean reward -20.386, speed 535.28 f/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-77c5937ba334> in <module>
#      24
#      25 with common.RewardTracker(writer, stop_reward=18) as tracker:
# ---> 26     for step_idx, exp in enumerate(exp_source):
#      27         baseline_buf.add(exp.reward)
#      28         baseline = baseline_buf.mean()
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/ptan/experience.py in __iter__(self)
#     174
#     175     def __iter__(self):
# --> 176         for exp in super(ExperienceSourceFirstLast, self).__iter__():
#     177             if exp[-1].done and len(exp) <= self.steps:
#     178                 last_state = None
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/ptan/experience.py in __iter__(self)
#      92                     next_state_n, r_n, is_done_n, _ = env.step(action_n)
#      93                 else:
# ---> 94                     next_state, r, is_done, _ = env.step(action_n[0])
#      95                     next_state_n, r_n, is_done_n = [next_state], [r], [is_done]
#      96
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/gym/core.py in step(self, action)
#     271
#     272     def step(self, action):
# --> 273         observation, reward, done, info = self.env.step(action)
#     274         return observation, self.reward(reward), done, info
#     275
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/ptan/common/wrappers.py in step(self, action)
#     194
#     195     def step(self, action):
# --> 196         ob, reward, done, info = self.env.step(action)
#     197         self.frames.append(ob)
#     198         return self._get_ob(), reward, done, info
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/gym/core.py in step(self, action)
#     259
#     260     def step(self, action):
# --> 261         observation, reward, done, info = self.env.step(action)
#     262         return self.observation(observation), reward, done, info
#     263
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/gym/core.py in step(self, action)
#     260     def step(self, action):
#     261         observation, reward, done, info = self.env.step(action)
# --> 262         return self.observation(observation), reward, done, info
#     263
#     264     def observation(self, observation):
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/ptan/common/wrappers.py in observation(self, obs)
#     134
#     135     def observation(self, obs):
# --> 136         return ProcessFrame84.process(obs)
#     137
#     138     @staticmethod
#
# ~/envs/reinforcement_learning/lib/python3.6/site-packages/ptan/common/wrappers.py in process(frame)
#     144         else:
#     145             assert False, "Unknown resolution."
# --> 146         img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
#     147         resized_screen = cv2.resize(img, (84, 110), interpolation=cv2.INTER_AREA)
#     148         x_t = resized_screen[18:102, :]
#
# KeyboardInterrupt:
